# %%
# %pip install xgboost
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.1 is available.
# You should consider upgrading via the 'c:\Users\mhira\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor

# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)

def score_dataset(X, y, model=XGBRegressor()):
    # Label encoding for categoricals
    for colname in X.select_dtypes(["category", "object"]):
        X[colname], _ = X[colname].factorize()
    # Metric for Housing competition is RMSLE (Root Mean Squared Log Error)
    score = cross_val_score(
        model, X, y, cv=5, scoring="neg_mean_squared_log_error",
    )
    score = -1 * score.mean()
    score = np.sqrt(score)
    return score

# %%
train = pd.read_csv('./input/train.csv')
test = pd.read_csv('./input/test.csv')

train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
all_df = pd.concat([train, test], axis=0)
all_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
# 文字列の特徴量を抽出
object_cols = []
num_cols = []
for col in all_df.columns:
    if(all_df[col].dtype == 'object'):
        object_cols.append(col)
    else:
        num_cols.append(col)

# %%
# 数値化
for col in object_cols:
    le = LabelEncoder()
    print(col)
    all_df[col].fillna('missing', inplace=True)
    all_df[col] = le.fit_transform(all_df[col])
    all_df[col] = all_df[col].astype('category')
# Out:
# MSZoning
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# PoolQC
# Fence
# MiscFeature
# SaleType
# SaleCondition

# %%
# 学習用と検証用に分割
train = all_df.loc[all_df['SalePrice'].notnull()]
test = all_df.loc[all_df['SalePrice'].isnull()]
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60        3         65.0     8450      1     2        3
# 1        2          20        3         80.0     9600      1     2        3
# 2        3          60        3         68.0    11250      1     2        0
# 3        4          70        3         60.0     9550      1     2        0
# 4        5          60        3         84.0    14260      1     2        0
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60        3         62.0     7917      1     2        3
# 1456  1457          20        3         85.0    13175      1     2        3
# 1457  1458          70        3         66.0     9042      1     2        3
# 1458  1459          20        3         68.0     9717      1     2        3
# 1459  1460          20        3         75.0     9937      1     2        3
#
# ...

# %%
x = train.drop(['SalePrice', 'Id'], axis=1)
y = train['SalePrice']

# %%
score_dataset(x, y)
# Out:
# 0.14403538250461898

# %%
#学習
model = XGBRegressor()
model.fit(x, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20        2         80.0    11622      1     2        3
# 1     1462          20        3         81.0    14267      1     2        0
# 2     1463          60        3         74.0    13830      1     2        0
# 3     1464          60        3         78.0     9978      1     2        0
# 4     1465         120        3         43.0     5005      1     2        0
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160        4         21.0     1936      1     2        3
# 1455  2916         160        4         21.0     1894      1     2        3
# 1456  2917          20        3        160.0    20000      1     2        3
# 1457  2918          85        3         62.0    10441      1     2        3
# 1458  2919          60        3         74.0     9627      1     2        3
#
# ...

# %%
test1 = test.drop(['Id', 'SalePrice'], axis=1)
for colname in test1.select_dtypes(["category", "object"]):
    test1[colname], _ = test1[colname].factorize()
pred = model.predict(test1)
pred
# Out:
# array([136881.61 , 168324.2  , 189745.42 , ..., 167715.16 , 103369.086,
#        209236.61 ], dtype=float32)

# %%
sub2 = pd.Series(data=pred, index=test['Id'], name="SalePrice")
sub2.to_csv('./output/submission2.csv')
